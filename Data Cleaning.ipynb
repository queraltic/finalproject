# %%
import pandas as pd
import os
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import requests
import plotly.graph_objects as go
from statistics import mean
import kaleido
import seaborn.objects as so

#import kaleido
# %matplotlib inline

#READ THE DATA FRAME
df = pd.read_csv ('/Users/queraltiglesias/Desktop/FINALPROJECT/finalproject/data/FinalProject.csv')
df2 = pd.read_csv ('/Users/queraltiglesias/Desktop/FINALPROJECT/finalproject/data/FinalProject2.csv',)
df4 = pd.read_csv ('/Users/queraltiglesias/Desktop/FINALPROJECT/finalproject/data/FinalProject1 copia.csv',)

# %% [markdown]
# # Google Form for obtaning the main Data about Eating Disorder in Apps

# %%
df.head()
# Out:
#                  Marca temporal           Nombre de usuario Edad/Age:  \
# 0  2022/11/22 4:28:11 p. m. CET   joanaritamaia@hotmail.com     21-25
# 1  2022/11/22 4:33:27 p. m. CET     claraalmenara@gmail.com     25-30
# 2  2022/11/22 4:44:15 p. m. CET  jessicaesanchezc@gmail.com     21-25
# 3  2022/11/22 4:49:10 p. m. CET      dogsandcason@gmail.com     21-25
# 4  2022/11/22 4:51:14 p. m. CET   cresta_fons.0i@icloud.com     16-21
#
#       Sexo/Sex  \
# 0  Mujer/Woman
# 1  Mujer/Woman
# 2  Mujer/Woman
# 3  Mujer/Woman
# 4  Mujer/Woman
#
#   Paciente o especialista en salud mental/ patient or mental health specialist  \
# 0                                   Paciente/Patient
# 1                                   Paciente/Patient
# 2                                   Paciente/Patient
# 3                                   Paciente/Patient
# 4                                   Paciente/Patient
#
# ...

# %%
#Dates that are in the data frame
df.shape
# Out:
# (81, 16)

# %%
#DROP THE NA
df.dropna(how='all',inplace=True)

# %%
#NUMBER OF SAMPLES WE WANT TO SHOW

df.sample(81)
# Out:
#                    Marca temporal             Nombre de usuario Edad/Age:  \
# 32  2022/11/23 10:45:03 a. m. CET       sineranna2021@gmail.com       40+
# 42   2022/11/23 2:07:14 p. m. CET          agc12380@hotmail.com     16-21
# 6    2022/11/22 5:09:27 p. m. CET    adela.sanchez@ironhack.com     25-30
# 74  2022/11/24 10:52:23 a. m. CET          keoki.wiki@ymail.com       40+
# 31  2022/11/23 10:11:09 a. m. CET        riverwave222@gmail.com     21-25
# ..                            ...                           ...       ...
# 69  2022/11/23 11:56:54 p. m. CET       martacasals19@gmail.com     21-25
# 64   2022/11/23 9:52:25 p. m. CET          claraszy98@gmail.com     21-25
# 48   2022/11/23 2:49:00 p. m. CET          albamorell@gmail.com     25-30
# 59   2022/11/23 8:06:45 p. m. CET        sansmireia@hotmail.com     21-25
# 12   2022/11/22 5:17:02 p. m. CET  carlajuradocabra12@gmail.com     16-21
#
#        Sexo/Sex  \
# 32  Mujer/Woman
# 42  Mujer/Woman
# 6   Mujer/Woman
# ...

# %%
#COLUMNS THAT I WANT TO DROP

df.drop(['¿Sugerencias?','Marca temporal','Nombre de usuario'],axis=1,inplace=True)

# %%
df["¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist)."].unique()
# Out:
# array(['Sí/Yes', nan, 'No/No'], dtype=object)

# %%
df.dtypes
# Out:
# Edad/Age:                                                                                                                                                                                           object
# Sexo/Sex                                                                                                                                                                                            object
# Paciente o especialista en salud mental/ patient or mental health specialist                                                                                                                        object
# ¿Qué tipo de enfermedad mental has tenido respecto a la comida?/What kind of mental illness have you had regarding food?                                                                            object
# ...

# %%
#COLUMNS THAT ARE IN THE DATA AFTER DROPPING  

df.columns
# Out:
# Index(['Edad/Age:', 'Sexo/Sex',
#        'Paciente o especialista en salud mental/ patient or mental health specialist',
#        '¿Qué tipo de enfermedad mental has tenido respecto a la comida?/What kind of mental illness have you had regarding food?',
#        'Has usado alguna app recomendada por un especialista en salud mental?/Have you used an app recommended by a mental health specialist?',
#        'Sí, la respuesta es que sí, ¿cuál?/ if the answer is yes, which one?',
#        '¿Días sin atracones?/Count of days without binge eating?',
#        '¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist).',
#        ' ¿Frase motivacional?/ Motivational quote?',
#        '¿Apuntar comidas de cada dia?/Record daily meals?',
# ...

# %%
#Checking cumber of empty data cells
df.isnull().sum()
# Out:
# Edad/Age:                                                                                                                                                                                            0
# Sexo/Sex                                                                                                                                                                                             0
# Paciente o especialista en salud mental/ patient or mental health specialist                                                                                                                         0
# ¿Qué tipo de enfermedad mental has tenido respecto a la comida?/What kind of mental illness have you had regarding food?                                                                            10
# ...

# %%
df.dtypes
# Out:
# Edad/Age:                                                                                                                                                                                           object
# Sexo/Sex                                                                                                                                                                                            object
# Paciente o especialista en salud mental/ patient or mental health specialist                                                                                                                        object
# ¿Qué tipo de enfermedad mental has tenido respecto a la comida?/What kind of mental illness have you had regarding food?                                                                            object
# ...

# %%
sns.countplot(data=df, x= 'Has usado alguna app recomendada por un especialista en salud mental?/Have you used an app recommended by a mental health specialist?')
dtype={'caption' : str}
plt.title("Have you used an app recommended by a mental health specialist?")
plt.savefig("Have you used an app recommended by a mental health specialist?.png")

# %%
sns.countplot(data=df, x= '¿Días sin atracones?/Count of days without binge eating?')
dtype={'caption' : str}
plt.title("Count of days without binge eating?")
plt.savefig("Count of days without binge eating?")

# %%
df[df.columns[8]].astype(str)
f= {"Sí/Yes" : True, "No/No" : False}
df[df.columns[8]].map(f)
df[df.columns[8]].astype(bool)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 76    True
# 77    True
# 78    True
# 79    True
# 80    True
# Name:  ¿Frase motivacional?/ Motivational quote?, Length: 81, dtype: bool

# %%
sns.countplot(data=df, x= df.columns[8])
dtype={'caption' : str}
plt.title("Motivational Quote")
plt.savefig("Motivational Quote.png")

# %%
#Pass from object too Boolean
df['¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist).'] = df['¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist).'].astype(str)
d= {"Sí/Yes" : True, "No/No" : False}
df['¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist).'] = df['¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist).'].map(d)
df['¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist).'] = df['¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist).'].astype(bool)

# %%
df["¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist)."]
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 76     True
# 77    False
# 78     True
# 79     True
# 80     True
# Name: ¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist)., Length: 81, dtype: bool

# %%
sns.countplot(data=df, x= '¿Apuntar comidas de cada dia?/Record daily meals?')
dtype={'caption' : str}
plt.title("Record daily meals?")
plt.savefig("Record daily meals?.png")

# %%
sns.countplot(data=df, x= df.columns[11])
dtype={'caption' : str}
plt.title("List of helpful strategies?")
plt.savefig("Listofhelpfulstrategies.png")

# %%
sns.countplot(data=df, x="¿Botón de pánico? (Llamar a algún familiar, amigo, persona de confianza o especialista en salud mental)/Panic button?(call a family member, friend, trusted person or mental health specialist).")
dtype={'caption' : str}
plt.title("Panic Button")
plt.savefig("Panic Button.png")

# %%
#Pass from object too Boolean
df[df.columns[12]].astype(str)
e= {"Sí/Yes" : True, "No/No" : False}
df[df.columns[12]].map(e)
df[df.columns[12]].astype(bool)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 76    True
# 77    True
# 78    True
# 79    True
# 80    True
# Name: ¿Compartir tus datos con familia, amigos o conocidos para ver tus progresos?/Share your data with family, friends or acquaintances to see your progress?, Length: 81, dtype: bool

# %%
sns.countplot(data=df, x= df.columns[12])
dtype={'caption' : str}
plt.title("Share your data with family, friends or acquaintances to see your progress?")
plt.savefig("Share your data with family, friends or acquaintances to see your progress?.png")

# %% [markdown]
# # App Statistics

# %%
df2
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  Pre-test Assessment  \
# 0   CONDITION        Age        sex        BMI  Drive for Thinness
# 1          EC         18      women      20.18                   23
# 2          EC         21      women      23.15                   29
# 3          EC         19      women      19.14                   27
# 4          EC         22      women      20.57                   22
# ..        ...        ...        ...        ...                  ...
# 56    Neutral         23      women      16.81                   22
# 57    Neutral         19      women      20.20                   22
# 58    Neutral         19      women      18.83                   11
# 59    Neutral         20      women      17.37                   15
# 60    Neutral         20      women      26.73                   30
#
#                Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0   Body Dissatisfaction       CDRS        CESD      RSES
# ...

# %%
df2.dtypes
# Out:
# Unnamed: 0                        object
# Unnamed: 1                        object
# Unnamed: 2                        object
# Unnamed: 3                        object
# Pre-test Assessment               object
# Unnamed: 5                        object
# Unnamed: 6                        object
# Unnamed: 7                        object
# Unnamed: 8                        object
# Post-test Assessment              object
# Unnamed: 10                       object
# Unnamed: 11                       object
# Unnamed: 12                       object
# Unnamed: 13                       object
# Unnamed: 14                       object
# Unnamed: 15                       object
# App use                           object
# Unnamed: 17                       object
# Evolution Score pre/post-test     object
# Unnamed: 19                       object
# Unnamed: 20                       object
# Unnamed: 21                       object
# Unnamed: 22                       object
# ...

# %%
#OBJECT TO STR

df2['Age']=df2['Age'].astype(str).astype(int)
df2['Pre-Drive for Thinness']=df2['Pre-Drive for Thinness'].astype(str).astype(int)
df2["Pre-Body Dissatisfaction"]=df2["Pre-Body Dissatisfaction"].astype(str).astype(int)
df2["Pre-Bulimia"]=df2["Pre-Bulimia"].astype(str).astype(int)
df2["Pre-Bulimia"]=df2["Pre-Bulimia"].astype(str).astype(int)
df2["Post-Drive for Thinness"]=df2["Post-Drive for Thinness"].astype(str).astype(int)
df2["Pre-Body Dissatisfaction"]=df2["Pre-Body Dissatisfaction"].astype(str).astype(int)
df2["Post-Bulimia"]=df2["Post-Bulimia"].astype(str).astype(int)
#df2["Post-Drive for Thinness"]=df2["Post-Drive for Thinness "].astype(str).astype(int)
df2["Day use"]=df2["Day use"].astype(str).astype(int)
df2["Result-Drive for Thinness"]=df2["Result-Drive for Thinness"].astype(str).astype(int)
df2["Result-Body Dissatisfaction"]=df2["Result-Body Dissatisfaction"].astype(str).astype(int)
df2["Result-Bulimia"]=df2["Result-Bulimia"].astype(str).astype(int)
df2["Result-Restraint"]=df2["Result-Restraint"].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/ironhack/lib/python3.10/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
# ...

# %%
#Convert
df2['Age']=df2['Age'].astype(str).astype(int)

# %%
#Dates that are in the data frame
df2.shape
# Out:
# (60, 24)

# %%
#Drop the index
df2.reset_index(drop=True, inplace=True)

# %%
#Rename Columns
df2.rename(columns={ 'Pre-test Assessment':"Pre-Drive for Thinness"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 5':"Pre-Body Dissatisfaction"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 6':"Pre-Anorexia"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 7':"Pre-Bulimia"},inplace=True, errors="ignore")
df2.rename(columns={ 'Pre-Bulimia':"Pre-Restraint"},inplace=True, errors="ignore")
df2.rename(columns={ 'Post-Restraint':"Post-Drive for Thinness"},inplace=True, errors="ignore")
df2.rename(columns={ 'Pre-Body Dissatisfaction':"Post-Body Dissatisfaction"},inplace=True, errors="ignore")
df2.rename(columns={ 'Pre-Body Dissatisfaction':"Post-Body Dissatisfaction"},inplace=True, errors="ignore")
df2.rename(columns={ 'Post-test Assessment':"Post.Drive for Thinness"},inplace=True, errors="ignore")
df2.rename(columns={ 'Post.Drive for Thinness':"Post-Drive for Thinness"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 13':"Post-Anorexia"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 14':"Post-Bulimia"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 15':"Post-Restraint"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 17':"Day use"},inplace=True, errors="ignore")
df2.rename(columns={ 'Evolution Score pre/post-test':"Result-Drive for Thinness"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 19':"Result-Body Dissatisfaction"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 19':"Result-Body Dissatisfaction"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 20':"Result-Anorexia"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 21':"Result-Bulimia"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 22':"Result-Restraint"},inplace=True, errors="ignore")
df2.rename(columns={ 'Anorexia':"Pre-Anorexia"},inplace=True, errors="ignore")
df2.rename(columns={ 'Pre-Restraint':"Pre-Bulimia"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 8':"Pre-Restraint"},inplace=True, errors="ignore")
df2.rename(columns={ 'Post-Body Dissatisfaction':"Pre-Body Dissatisfaction"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 10':"Post-Body Dissatisfaction"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 1':"Age"},inplace=True, errors="ignore")
df2.rename(columns={ 'Unnamed: 2':"Sex"},inplace=True, errors="ignore")

# %%
#Average by age and column
df3=df2.groupby("Age").mean()
df3.head()
df3.to_csv('/Users/queraltiglesias/Desktop/FINALPROJECT/finalproject/FinalProject3.csv', index = False, encoding='utf-8')

# %%
df3.columns
# Out:
# Index(['Unnamed: 23'], dtype='object')

# %% [markdown]
# # Average result for every age

# %%
#COLUMNS THAT I WANT TO DROP

df2.drop([ 'Unnamed: 3', 'Unnamed: 23', 'App use','Unnamed: 11', 'Unnamed: 12',"Unnamed: 0",'Pre-Anorexia', 'Result-Anorexia','Post-Anorexia'],axis=1,inplace=True)

# %%
#LINE THAT ARE IN THE DATA AFTER DROPPING  

df2=df2.drop([0],axis=0)
df3
# Out:
#      Pre-Drive for Thinness  Pre-Body Dissatisfaction  Pre-Bulimia  \
# Age
# 16                30.000000                 46.000000    24.000000
# 18                23.833333                 35.250000    25.333333
# 19                19.350000                 29.350000    14.550000
# 20                23.538462                 35.769231    15.923077
# 21                24.500000                 36.500000    18.375000
# 22                26.000000                 34.000000    20.600000
# 23                22.000000                 30.000000    32.000000
#
#      Pre-Bulimia  Post-Drive for Thinness  Pre-Body Dissatisfaction  \
# Age
# 16     22.000000                16.000000                 41.000000
# 18     25.250000                21.750000                 34.833333
# 19     29.950000                16.450000                 28.000000
# 20     30.076923                18.538462                 33.384615
# 21     28.750000                21.500000                 35.875000
# ...

# %% [markdown]
# # Data Visualization

# %%
#TOTAL
sns.clustermap(df3)

# %%
g = sns.JointGrid(x="Pre-Drive for Thinness", y="Result-Drive for Thinness", data=df3)
g = g.plot(sns.regplot, sns.distplot)
title='Drive of Thinness'
plt.savefig("driveforthiness.png")
# Out:
# /Users/queraltiglesias/opt/anaconda3/envs/ironhack/lib/python3.10/site-packages/seaborn/axisgrid.py:1880: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /Users/queraltiglesias/opt/anaconda3/envs/ironhack/lib/python3.10/site-packages/seaborn/axisgrid.py:1886: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.regplot(data=df2,  x=df2["Age"], y=df2["Day use"],scatter=True).set(title='Age VS Day Use')
plt.savefig("Age VS Day Use.png")

# %%
sns.regplot(data=df3,  x=df3["Result-Drive for Thinness"], y=df3["Result-Bulimia"],scatter=True).set(title='Result Bulimia VS Result Drive for thiness')
plt.savefig('Result Bulimia VS Drive fot Thinness')

# %%
sns.regplot(data=df3,  x=df3["Result-Body Dissatisfaction"], y=df3["Result-Restraint"],scatter=True).set(title='Result restraint VS body dissatisfaction')
plt.savefig('Result Restraint VS Body Dissatisfacton')

# %%
import plotly.express as px
df1 = px.data.tips()
fig = px.bar(df, x="Edad/Age:", y="Sexo/Sex", color="Paciente o especialista en salud mental/ patient or mental health specialist", barmode="group")
plt.savefig("patient.png")
fig.show()

# %%
#hola = sns.load_dataset(df3).pivot("Age", "Task", "Score")
#sns.heatmap(df3)
sns.heatmap(df3, annot=True)
# Out:
# <AxesSubplot: ylabel='Age'>

# %%
#sns.ecdfplot(data=df, x="Sexo/Sex:",hue="Edad/Age:")
 #x="Sexo/Sex:",hue="Edad/Age:"

#sns.histplot(df, x="Edad/Age:", hue="Sexo/Sex:", element="step")
(
    so.Plot(df, x="Edad/Age:", y="Sexo/Sex", color="Paciente o especialista en salud mental/ patient or mental health specialist")
    .add(so.Dot(), so.Agg(), so.Dodge())
    .add(so.Range(), so.Est(errorbar="sd"), so.Dodge())
)

#sns.histplot(data=df, x="Sexo/Sex:")
